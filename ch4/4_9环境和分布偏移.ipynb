# %% [markdown]
# # 4.9 环境与分布偏移
#
# ## 4.9.1 分布偏移的类型
# > 幸运的是，在对未来我们的数据可能发生变化的一些限制性假设下，有些算法可以检测这种偏移，甚可以动态调整，提高原始分类器的精度。
# ### 协变量偏移
#
# ### 标签偏移
#
# ### 概念偏移
# 我们希望利用在时间上或空间上逐渐发生偏移的知识，并有相适应的方法
#
# ## 4.9.3 分布偏移的纠正
#
# ### 经验风险与实际风险
# 我们实际上，在做的事情，是用经验风险来模拟实际风险，尽可能经验风险最小化
#
# ### 协变量偏移纠正
# ![image.png](attachment:f424ad03-9a04-4922-a016-390e69735fe9.png)
# 加权经验风险最小化来训练模型，而比率的估计需要另外的方法，
